# %%
# !pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
base= pd.read_csv('/content/sample_data/paoemanteiga.csv', sep=';',encoding='cp1252', header=None)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
products = base.columns[1:]
transaction_list = []
for index, row in base.iterrows():
    transaction = [products[i] for i in range(len(products)) if row[i + 1] != 'Sim']  # Itens ausentes
    transaction_list.append(transaction)

te = TransactionEncoder()
te_ary = te.fit(transaction_list).transform(transaction_list)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         1      2      3      4      5      6
# 0    True   True   True   True   True   True
# 1   False   True  False  False   True   True
# 2    True  False  False  False   True   True
# 3   False   True  False  False   True   True
# 4   False   True  False  False   True   True
# 5    True  False   True   True   True   True
# 6    True   True   True  False   True   True
# 7    True   True  False   True   True   True
# 8    True   True   True   True   True  False
# 9    True   True   True   True  False  False
# 10   True   True   True   True  False   True

# %%
itemsets = apriori(df, min_support=0.3, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
regras = association_rules(itemsets, metric="confidence", min_threshold=0.8)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
item_mapping = {index: product for index, product in enumerate(products)}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print("Regras geradas:")
for index, row in regras.iterrows():
    antecedent_items = [item_mapping.get(item, item) for item in row['antecedents']]
    consequent_items = [item_mapping.get(item, item) for item in row['consequents']]
    antecedent_items = [str(item) for item in antecedent_items]
    consequent_items = [str(item) for item in consequent_items]
    print(f"Quem não leva {', '.join(antecedent_items)} leva {', '.join(consequent_items)}")
# Out:
# Regras geradas:
# Quem não leva 4 leva 2
# Quem não leva 5 leva 2
# Quem não leva 4 leva 3
# Quem não leva 5 leva 3
# Quem não leva 4 leva 5
# Quem não leva 5 leva 4
# Quem não leva 6 leva 6
# Quem não leva 6 leva 6
# Quem não leva 2, 3 leva 4
# Quem não leva 2, 4 leva 3
# Quem não leva 3, 4 leva 2
# Quem não leva 4 leva 2, 3
# Quem não leva 2, 3 leva 5
# Quem não leva 2, 5 leva 3
# Quem não leva 3, 5 leva 2
# Quem não leva 5 leva 2, 3
# Quem não leva 2, 4 leva 5
# Quem não leva 2, 5 leva 4
# Quem não leva 4, 5 leva 2
# Quem não leva 4 leva 2, 5
# Quem não leva 5 leva 2, 4
# Quem não leva 4, 6 leva 2
# Quem não leva 4, 6 leva 2
# Quem não leva 5, 6 leva 2
# Quem não leva 5, 6 leva 2
# Quem não leva 2, 6 leva 6
# Quem não leva 2, 6 leva 6
# Quem não leva 3, 4 leva 5
# Quem não leva 3, 5 leva 4
# Quem não leva 4, 5 leva 3
# Quem não leva 3, 6 leva 6
# Quem não leva 3, 6 leva 6
# Quem não leva 2, 3, 4 leva 5
# Quem não leva 2, 3, 5 leva 4
# Quem não leva 2, 4, 5 leva 3
# ...
